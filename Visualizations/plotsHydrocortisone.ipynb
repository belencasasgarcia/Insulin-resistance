# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from paper_behavior_functions import (seaborn_style, 
                                      group_colors, figpath,
                                      FIGURE_WIDTH, FIGURE_HEIGHT)

# Load some things from paper_behavior_functions
figpath = figpath()
seaborn_style()
pal = group_colors()

color1=[0, 0.25, 0.5]
color2=[0.584, 0.84, 0.96]

# Create an array with the colors we want to use
colors = [[0.92,0.68,0.0353],[0.8,0,0.2]] #Red, yellow
colors1 = [[0.8,0,0.2], [0.92,0.68,0.0353]]
colors2 = [color1, color2]


# Set custom color palette
customPalette = sns.set_palette(sns.color_palette(colors))


customPalette1 = sns.set_palette(sns.color_palette(colors1))

#customPalette2 = sns.set_palette(sns.color_palette(colors2))

simulationsHC = pd.read_csv (r'HC_simulations2.csv') 
dataHC = pd.read_csv (r'HC_data.csv') 

dataHC['time_days']=dataHC['time']/24

simulationsHC['time_days']=simulationsHC['time']/24

dataHC["I_mean_highHC"]=dataHC["I_mean_highHC"]*6.9444*0.001
dataHC["I_SD_highHC"]=dataHC["I_SD_highHC"]*6.9444*0.001
dataHC["I_mean_low_HC"]=dataHC["I_mean_low_HC"]*6.9444*0.001
dataHC["I_SD_low_HC"]=dataHC["I_SD_low_HC"]*6.9444*0.001

simulationsHC['Imeasured_min_11mM']=simulationsHC['Imeasured_min_11mM']*6.9444*0.001
simulationsHC['Imeasured_max_11mM']=simulationsHC['Imeasured_max_11mM']*6.9444*0.001
simulationsHC['Imeasured_min_5p5mM']=simulationsHC['Imeasured_min_5p5mM']*6.9444*0.001
simulationsHC['Imeasured_max_5p5mM']=simulationsHC['Imeasured_max_5p5mM']*6.9444*0.001
simulationsHC['Imeasured_min_11mM_lowHC']=simulationsHC['Imeasured_min_11mM_lowHC']*6.9444*0.001
simulationsHC['Imeasured_max_11mM_lowHC']=simulationsHC['Imeasured_max_11mM_lowHC']*6.9444*0.001
simulationsHC['Imeasured_min_5p5mM_lowHC']=simulationsHC['Imeasured_min_5p5mM_lowHC']*6.9444*0.001
simulationsHC['Imeasured_max_5p5mM_lowHC']=simulationsHC['Imeasured_max_5p5mM_lowHC']*6.9444*0.001

# %%
simulationsHC.tail()
#dataHC.head()
# Out:
#       Gmeasured_max_11mM  Gmeasured_min_11mM  Gmeasured_opt_11mM  \
# 7196           10.758311            6.931027           10.126681
# 7197           10.758269            6.928972           10.126104
# 7198           10.758227            6.926918           10.125527
# 7199           10.758184            6.924864           10.124950
# 7200           10.758142            6.922812           10.124373
#
#       Imeasured_max_11mM  Imeasured_min_11mM  Imeasured_opt_11mM    time  \
# 7196            2.173264            1.759107          307.669713  359.80
# 7197            2.172947            1.758601          307.649358  359.85
# 7198            2.172629            1.758094          307.628917  359.90
# 7199            2.172311            1.757587          307.608390  359.95
# 7200            2.171993            1.757079          307.587777  360.00
#
#       Gmeasured_max_5p5mM  Gmeasured_min_5p5mM  Gmeasured_opt_5p5mM  ...  \
# ...

# %%
customPalette1

# %%
dataHC.tail()
# Out:
#      time  G_mean_highHC  G_SD_highHC  I_mean_highHC  I_SD_highHC  \
# 9   288.0         12.801     2.333621            NaN          NaN
# 10  296.0            NaN          NaN            NaN          NaN
# 11  312.0         10.790     2.111483            NaN          NaN
# 12  336.0         10.177     2.093797       0.441969     0.486166
# 13  359.9         10.187     2.094086       0.618142     0.503784
#
#     ratioSDmean Glycemic_level  G_mean_high_HC_normo  G_SD_high_HC_normo  \
# 9       #DIV/0!  Normoglycemia                   NaN                 NaN
# 10      #DIV/0!  Normoglycemia                   NaN                 NaN
# 11          110  Normoglycemia                   NaN                 NaN
# 12          110  Normoglycemia                   NaN                 NaN
# 13  81.49966859  Normoglycemia                   NaN                 NaN
#
#     I_mean_high_HC_normo  I_SD_high_HC_normo  G_mean_lowHC  G_SD_lowHC  \
# ...

# %%
# Glucose days 1-3

simulation_GTT = simulationsHC[simulationsHC['time']<=48]
plt.close('all')

fig = sns.FacetGrid(data=dataHC, hue="Glycemic_level", palette=customPalette1,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

#fig.map(plt.errorbar, "time_total", "Glucose_mean", "Glucose_SEM", fmt='none')
fig.map(plt.errorbar, "time_days", "G_mean_highHC", "G_SD_highHC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3)
sns.lineplot(data=dataHC,
             x='time_days', y='G_mean_highHC', hue="Glycemic_level", marker='o', err_style='bars',
             color=customPalette1, linewidth=0, ci=95, ax=fig.ax, legend=None)# overlay the simulated


fig.ax.fill_between(data=simulation_GTT, x='time_days', y1='Gmeasured_min_11mM', y2='Gmeasured_max_11mM', alpha=0.45, 
                    facecolor=colors[1])

#fig.ax.fill_between(data=simulation_GTT, x='time_days', y1='Gmeasured_min_5p5mM', y2='Gmeasured_max_5p5mM', alpha=0.5, 
#                    facecolor=colors[0])


fig.set_axis_labels('Time (days)', 'Glucose (mM)')
fig.ax.set_xticks([0,1,2])
fig.ax.set_xticklabels(['1','2','3'])
fig.ax.set_xlim(-0.3,2.3)
fig.ax.set_ylim(3,16)
fig.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig.savefig(os.path.join(figpath, "training_glucose_HC_day1to3.pdf"))
# Out:
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
# Glucose days 13-15


simulation_GTT = simulationsHC[(simulationsHC['time']>=288) & (simulationsHC['time']<=336)]
plt.close('all')

fig = sns.FacetGrid(data=dataHC, hue="Glycemic_level", palette=customPalette,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

#fig.map(plt.errorbar, "time_total", "Glucose_mean", "Glucose_SEM", fmt='none')
fig.map(plt.errorbar, "time_days", "G_mean_highHC", "G_SD_highHC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3)
sns.lineplot(data=dataHC,
             x='time_days', y='G_mean_highHC', hue="Glycemic_level", marker='o', err_style='bars',
             color=customPalette, linewidth=0, ci=95, ax=fig.ax, legend=None)# overlay the simulated


fig.ax.fill_between(data=simulation_GTT, x='time_days', y1='Gmeasured_min_11mM', y2='Gmeasured_max_11mM', alpha=0.45, 
                    facecolor=colors[1])

fig.ax.fill_between(data=simulation_GTT, x='time_days', y1='Gmeasured_min_5p5mM', y2='Gmeasured_max_5p5mM', alpha=0.45, 
                    facecolor=colors[0])


fig.set_axis_labels('Time (days)', 'Glucose (mM)')
fig.ax.set_xticks([12,13,14])
fig.ax.set_xticklabels(['13','14','15'])
fig.ax.set_xlim(11.5,14.5)
fig.ax.set_ylim(3,16)
fig.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig.savefig(os.path.join(figpath, "training_glucose_HC_day13to15.pdf"))
# Out:
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
288+48
# Out:
# 336

# %%
simulation_GTT.head()
# Out:
#       Gmeasured_max_11mM  Gmeasured_min_11mM  Gmeasured_opt_11mM  \
# 5760           11.153210            9.779066           10.990170
# 5761           11.152724            9.777862           10.989554
# 5762           11.152238            9.776658           10.988937
# 5763           11.151751            9.775455           10.988321
# 5764           11.151265            9.774251           10.987704
#
#       Imeasured_max_11mM  Imeasured_min_11mM  Imeasured_opt_11mM    time  \
# 5760            0.026772            0.000316            3.668177  288.00
# 5761            0.032328            0.005903            4.451944  288.05
# 5762            0.037882            0.010566            5.235483  288.10
# 5763            0.043434            0.015225            6.018651  288.15
# 5764            0.048982            0.019882            6.801319  288.20
#
#       Gmeasured_max_5p5mM  Gmeasured_min_5p5mM  Gmeasured_opt_5p5mM  ...  \
# ...

# %%
customPalette1 = sns.set_palette(sns.color_palette(colors1))

simulation_GTT = simulationsHC[simulationsHC['time']<=48]
plt.close('all')


fig2 = sns.FacetGrid(data=dataHC, 
                    palette=customPalette1,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

fig2.map(plt.errorbar, "time_days", "I_mean_highHC", "I_SD_highHC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3,
       alpha=1)

sns.lineplot(data=dataHC,
             x='time_days', y="I_mean_highHC", marker='o', err_style='bars',
             color=customPalette1, linewidth=0, ci=95, ax=fig2.ax, legend=None, alpha=0.5)

fig2.ax.fill_between(data=simulation_GTT, x='time_days', y1='Imeasured_min_11mM', y2='Imeasured_max_11mM', alpha=0.45, 
                    facecolor=colors[1])

fig2.set_axis_labels('Time (days)', 'Insulin (nM)')
fig2.ax.set_xticks([0,1,2])
fig2.ax.set_xticklabels(['1','2','3'])
fig2.ax.set_xlim(-0.3,2.3)
fig2.ax.set_ylim(0,30)
fig2.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig2.savefig(os.path.join(figpath, "training_insulin_HC_day1to3.pdf"))

# %%
simulation_GTT_d13 = simulationsHC.copy()

simulation_GTT_d13 = simulation_GTT_d13[(simulationsHC['time']>=288) & (simulationsHC['time']<=336)]

plt.close('all')

fig = sns.FacetGrid(data=dataHC, hue="Glycemic_level", palette=customPalette1,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

#fig.map(plt.errorbar, "time_total", "Glucose_mean", "Glucose_SEM", fmt='none')
fig.map(plt.errorbar, "time_days", "I_mean_highHC", "I_SD_highHC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3, alpha=1)
sns.lineplot(data=dataHC,
             x='time_days', y='I_mean_highHC', hue="Glycemic_level", marker='o', err_style='bars',
             color=customPalette, linewidth=0, ci=95, ax=fig.ax, legend=None, alpha=0.5)# overlay the simulated


fig.ax.fill_between(data=simulation_GTT_d13, x='time_days', y1='Imeasured_min_11mM', y2='Imeasured_max_11mM', alpha=0.45, 
                    facecolor=colors[1])

fig.ax.fill_between(data=simulation_GTT_d13, x='time_days', y1='Imeasured_min_5p5mM', y2='Imeasured_max_5p5mM', alpha=0.45, 
                    facecolor=colors[0])


fig.set_axis_labels('Time (days)', 'Insulin (nM)')
fig.ax.set_xticks([12,13,14])
fig.ax.set_xticklabels(['13','14','15'])
fig.ax.set_xlim(11.5,14.5)
fig.ax.set_ylim(0,30)
fig.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig.savefig(os.path.join(figpath, "training_insulin_HC_day13to16.pdf"))
# Out:
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
# Glucose days 1-3, low HC

customPalette2 = sns.set_palette(sns.color_palette(colors2))

simulation_GTT = simulationsHC[simulationsHC['time']<=48]
plt.close('all')

fig = sns.FacetGrid(data=dataHC, hue="Glycemic_level", palette=customPalette,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

#fig.map(plt.errorbar, "time_total", "Glucose_mean", "Glucose_SEM", fmt='none')
fig.map(plt.errorbar, "time_days", "G_mean_lowHC", "G_SD_lowHC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3)
sns.lineplot(data=dataHC[dataHC['time_days'] > 0],
             x='time_days', y='G_mean_lowHC', hue="Glycemic_level", marker='X', err_style='bars',
             color=customPalette1, linewidth=0, ci=95, ax=fig.ax, legend=None)# overlay the simulated

sns.lineplot(data=dataHC[dataHC['time_days'] == 0],
             x='time_days', y='G_mean_lowHC', hue="Glycemic_level", marker="X", err_style='bars',
             color=customPalette1, linewidth=0, ci=95, ax=fig.ax, legend=None)# overlay the simulated



fig.ax.fill_between(data=simulation_GTT, x='time_days', y1='Gmeasured_min_11mM_lowHC', y2='Gmeasured_max_11mM_lowHC', alpha=0.45, 
                    facecolor=colors2[0])

#fig.ax.fill_between(data=simulation_GTT, x='time_days', y1='Gmeasured_min_5p5mM', y2='Gmeasured_max_5p5mM', alpha=0.5, 
#                    facecolor=colors[0])


fig.set_axis_labels('Time (days)', 'Glucose (mM)')
fig.ax.set_xticks([0,1,2])
fig.ax.set_xticklabels(['1','2','3'])
fig.ax.set_xlim(-0.3,2.3)
fig.ax.set_ylim(3,16)
fig.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig.savefig(os.path.join(figpath, "training_glucose_HC_day1to3_lowHC.pdf"))
# Out:
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
simulation_GTT = simulationsHC[simulationsHC['time']<=48]
plt.close('all')


fig2 = sns.FacetGrid(data=dataHC, 
                    palette=customPalette,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

fig2.map(plt.errorbar, "time_days", "I_mean_low_HC", "I_SD_low_HC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3,
       alpha=1)

sns.lineplot(data=dataHC,
             x='time_days', y="I_mean_low_HC", marker='X', err_style='bars',
             color=customPalette1, linewidth=0, ci=95, ax=fig2.ax, legend=None, alpha=0.5)

fig2.ax.fill_between(data=simulation_GTT, x='time_days', y1='Imeasured_min_11mM_lowHC', y2='Imeasured_max_11mM_lowHC', alpha=0.45, 
                    facecolor=colors2[0])

fig2.set_axis_labels('Time (days)', 'Insulin (nM)')
fig2.ax.set_xticks([0,1,2])
fig2.ax.set_xticklabels(['1','2','3'])
fig2.ax.set_xlim(-0.3,2.3)
fig2.ax.set_ylim(0,30)
fig2.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig2.savefig(os.path.join(figpath, "training_insulin_HC_day1to3_lowHC.pdf"))

# %%
simulation_GTT = simulationsHC[simulationsHC['time']>=288]
plt.close('all')

simulation_GTT_d13 = simulation_GTT_d13[(simulation_GTT_d13['time']>=288) & (simulation_GTT_d13['time']<=336)]

fig = sns.FacetGrid(data=dataHC, hue="Glycemic_level", palette=customPalette,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

#fig.map(plt.errorbar, "time_total", "Glucose_mean", "Glucose_SEM", fmt='none')
fig.map(plt.errorbar, "time_days", "G_mean_lowHC", "G_SD_lowHC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3)
sns.lineplot(data=dataHC,
             x='time_days', y='G_mean_lowHC', hue="Glycemic_level", marker='o', err_style='bars',
             color=customPalette, linewidth=0, ci=95, ax=fig.ax, legend=None)# overlay the simulated


fig.ax.fill_between(data=simulation_GTT_d13, x='time_days', y1='Gmeasured_min_11mM_lowHC', y2='Gmeasured_max_11mM_lowHC', alpha=0.45, 
                    facecolor=colors2[0])

fig.ax.fill_between(data=simulation_GTT_d13, x='time_days', y1='Gmeasured_min_5p5mM_lowHC', y2='Gmeasured_max_5p5mM_lowHC', alpha=0.45, 
                    facecolor=colors2[1])


fig.set_axis_labels('Time (days)', 'Glucose (mM)')
fig.ax.set_xticks([12,13,14])
fig.ax.set_xticklabels(['13','14','15'])
fig.ax.set_xlim(11.5,14.5)
fig.ax.set_ylim(3,16)
fig.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig.savefig(os.path.join(figpath, "prediction_glucose_HC_day13to16_lowHC.pdf"))
# Out:
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
customPalette2 = sns.set_palette(sns.color_palette(colors2))

simulation_GTT_d13 = simulationsHC.copy()

simulation_GTT_d13 = simulation_GTT_d13[(simulation_GTT_d13['time']>=288) & (simulation_GTT_d13['time']<=336)]

plt.close('all')

fig = sns.FacetGrid(data=dataHC, hue="Glycemic_level", palette=customPalette2,
                    sharex=True, sharey=True,
                    height=FIGURE_HEIGHT, aspect=(FIGURE_WIDTH/5)/FIGURE_HEIGHT)

#fig.map(plt.errorbar, "time_total", "Glucose_mean", "Glucose_SEM", fmt='none')
fig.map(plt.errorbar, "time_days", "I_mean_low_HC", "I_SD_low_HC", fmt='none', elinewidth=1, capsize=0.5, capthick=0.3, alpha=1)
sns.lineplot(data=dataHC,
             x='time_days', y='I_mean_low_HC', hue="Glycemic_level", marker='o', err_style='bars',
             color=customPalette, linewidth=0, ci=95, ax=fig.ax, legend=None, alpha=0.5)# overlay the simulated


fig.ax.fill_between(data=simulation_GTT_d13, x='time_days', y1='Imeasured_min_11mM_lowHC', y2='Imeasured_max_11mM_lowHC', alpha=0.3, 
                    facecolor=colors2[0])

fig.ax.fill_between(data=simulation_GTT_d13, x='time_days', y1='Imeasured_min_5p5mM_lowHC', y2='Imeasured_max_5p5mM_lowHC', alpha=0.3, 
                    facecolor=colors2[1])


fig.set_axis_labels('Time (days)', 'Insulin (nM)')
fig.ax.set_xticks([12,13,14])
fig.ax.set_xticklabels(['13','14','15'])
fig.ax.set_xlim(11.5,14.5)
fig.ax.set_ylim(0,30)
fig.despine(trim=True)
plt.tight_layout(w_pad=-0.1)
fig.savefig(os.path.join(figpath, "prediction_insulin_HC_day13to16_lowHC.pdf"))
# Out:
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
# /Users/belen/opt/anaconda3/envs/manuscript_IR/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)
